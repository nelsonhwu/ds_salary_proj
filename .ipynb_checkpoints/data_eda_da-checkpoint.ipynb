# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned_da.csv')

# %%
df.head()
# Out:
#                            Job Title              Salary Estimate  \
# 0   Tactical Data Link (TDL) Analyst   $53K-$95K (Glassdoor est.)
# 1                       Data Analyst   $33K-$57K (Glassdoor est.)
# 2   Senior, Measurement Data Analyst  $65K-$112K (Glassdoor est.)
# 3  Lead IT Analyst - Data Governance   $46K-$82K (Glassdoor est.)
# 4     Population Health Data Analyst   $47K-$83K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Overview:\r\n\r\nOasis Systems has an exciting...     3.8
# 1  Job Details\r\nDescription\r\nMetroNet has an ...     4.5
# 2  Position Summary\r\nPerforms data analysis to ...     3.5
# 3  About JLG, an Oshkosh company\r\n\r\nJLG began...     4.2
# 4  POSITION PURPOSE:\r\nThe Population Health Dat...     4.0
#
#                        Company Name           Location  Headquarters  \
# 0          Oasis Systems LLC\r\n3.8        Hampton, VA            -1
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'company_age', 'python_yn', 'R_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data analyst' in title.lower():
        return 'data analyst'
    elif 'analyst' in title.lower():
        return 'data analyst'
    elif 'data' in title.lower():
        return 'data analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
# Simplify job titles
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data analyst    629
# Name: job_simp, dtype: int64

# %%
# Parse out seniority levels
df['seniority'] = df['Job Title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# na        589
# senior     38
# jr          2
# Name: seniority, dtype: int64

# %%
# Job description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      4071
# 1      3379
# 2      5515
# 3      5702
# 4      3666
#        ...
# 624    1646
# 625    1394
# 626    2294
# 627    1528
# 628    7063
# Name: desc_len, Length: 629, dtype: int64

# %%
# hourly wage to annual
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis = 1)

# %%
df[df.hourly ==1][['hourly','min_salary', 'max_salary']]
# Out:
# Empty DataFrame
# Columns: [hourly, min_salary, max_salary]
# Index: []

# %%
df['company_text']
# Out:
# 0                    Oasis Systems LLC\r\n
# 1                             MetroNet\r\n
# 2            Enable Midstream Partners\r\n
# 3                  Oshkosh Corporation\r\n
# 4                          Vail Health\r\n
#                       ...
# 624    Greater Chicago Food Depository\r\n
# 625                             eNGINE\r\n
# 626                            Optimal\r\n
# 627                       OnShift, Inc\r\n
# 628                       Gate Gourmet\r\n
# Name: company_text, Length: 629, dtype: object

# %%
#remove new line from job title
df['company_text'] = df.company_text.apply(lambda x: x.replace('\r', '').replace('\n', ''))
df['company_text']
# Out:
# 0                    Oasis Systems LLC
# 1                             MetroNet
# 2            Enable Midstream Partners
# 3                  Oshkosh Corporation
# 4                          Vail Health
#                     ...
# 624    Greater Chicago Food Depository
# 625                             eNGINE
# 626                            Optimal
# 627                       OnShift, Inc
# 628                       Gate Gourmet
# Name: company_text, Length: 629, dtype: object

# %%
df.describe()
# Out:
#            Rating  Headquarters      Founded  Competitors  hourly  \
# count  629.000000         629.0   629.000000        629.0   629.0
# mean     3.711924          -1.0  1736.620032         -1.0     0.0
# std      0.544604           0.0   641.499711          0.0     0.0
# min      1.000000          -1.0    -1.000000         -1.0     0.0
# 25%      3.400000          -1.0  1924.000000         -1.0     0.0
# 50%      3.700000          -1.0  1985.000000         -1.0     0.0
# 75%      4.000000          -1.0  2001.000000         -1.0     0.0
# max      5.000000          -1.0  2019.000000         -1.0     0.0
#
#        employer_provided  min_salary  max_salary  avg_salary  company_age  \
# count         629.000000  629.000000  629.000000  629.000000   629.000000
# mean            0.001590   47.848967   85.222576   66.535771    42.282989
# std             0.039873   15.940407   25.892196   20.722439    48.701738
# min             0.000000   26.000000   47.000000   36.500000    -1.000000
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'company_age', 'python_yn', 'R_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority',
#        'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.company_age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column=['company_age', 'avg_salary', 'Rating'])

# %%
df.boxplot(column = 'Rating')

# %%
df[['company_age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#              company_age  avg_salary    Rating  desc_len
# company_age     1.000000    0.108468 -0.031929  0.196989
# avg_salary      0.108468    1.000000  0.132227 -0.009598
# Rating         -0.031929    0.132227  1.000000 -0.050421
# desc_len        0.196989   -0.009598 -0.050421  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['company_age', 'avg_salary', 'Rating', 'desc_len']].corr(), vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'company_age', 'python_yn', 'R_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority',
#        'desc_len'],
#       dtype='object')

# %%
# Categorical variables
df_cat = df[['Location', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue','company_text','job_state','python_yn', 'R_yn',
       'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority' ]]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("Graph for %s: Total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# Graph for Location: Total = 226
# Graph for Size: Total = 8
# Graph for Type of ownership: Total = 11
# Graph for Industry: Total = 72
# Graph for Sector: Total = 25
# Graph for Revenue: Total = 13
# Graph for company_text: Total = 400
# Graph for job_state: Total = 39
# Graph for python_yn: Total = 2
# Graph for R_yn: Total = 1
# Graph for spark_yn: Total = 2
# Graph for aws_yn: Total = 2
# Graph for excel_yn: Total = 2
# Graph for sql_yn: Total = 2
# Graph for job_simp: Total = 1
# Graph for seniority: Total = 3

# %%
for i in df_cat[['Location', 'company_text']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("Graph for %s: Total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: Total = 20
# Graph for company_text: Total = 20

# %%
pd.pivot_table(df, index = ['job_simp', 'seniority'], values = 'avg_salary')
# Out:
#                         avg_salary
# job_simp     seniority
# data analyst jr          68.000000
#              na          64.584041
#              senior      96.710526

# %%
pd.pivot_table(df, index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
#  MN         90.166667
#  OK         88.500000
#  IA         82.200000
#  FL         82.145161
#  CA         81.406250
#  WV         77.500000
#  AR         77.000000
#  NE         76.500000
#  WA         71.615385
#  CT         71.125000
#  VA         70.039474
#  RI         69.500000
#  GA         68.750000
#  OR         68.222222
#  AZ         67.200000
#  NY         67.090164
#  DC         65.586957
#  MA         64.620690
#  NJ         64.222222
#  AL         63.500000
#  MD         63.444444
#  SC         62.300000
#  TX         60.838710
#  UT         60.800000
#  WI         60.125000
#  TN         59.550000
#  NC         59.500000
#  PA         59.195652
#  MI         57.357143
#  NM         57.000000
#  IL         56.718750
#  OH         56.593750
#  KY         55.500000
#  MS         55.000000
#  KS         55.000000
#  CO         53.187500
#  LA         52.000000
#  MO         50.312500
#  IN         50.100000

# %%
pd.pivot_table(df, index = 'job_state', values = 'avg_salary', aggfunc='count').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
#  VA                76
#  CA                64
#  NY                61
#  DC                46
#  IL                32
#  FL                31
#  TX                31
#  MA                29
#  MD                27
#  NC                24
#  PA                23
#  NJ                18
#  OH                16
#  MI                14
#  WA                13
#  GA                12
#  IN                10
#  UT                10
#  TN                10
#  AZ                10
#  OR                 9
#  WI                 8
#  CO                 8
#  MO                 8
#  AL                 7
#  SC                 5
#  IA                 5
#  MS                 4
#  CT                 4
#  NM                 3
#  MN                 3
#  NE                 1
#  OK                 1
#  AR                 1
#  RI                 1
#  LA                 1
#  KY                 1
#  KS                 1
#  WV                 1

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'company_age', 'python_yn', 'R_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority',
#        'desc_len'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'employer_provided', 'python_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'seniority', 'Type of ownership', 'avg_salary']]

# %%
pd.set_option('display.max_rows', None)

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
# 2.3      87.500000
# 4.5      80.043478
# 5.0      78.750000
# 3.8      77.991667
# 4.3      72.821429
# 3.5      71.000000
# 2.5      67.600000
# 3.7      67.572581
# 4.6      66.560000
# 4.4      66.472222
# 3.9      66.333333
# 3.6      65.696970
# 4.2      65.695652
# 3.2      65.166667
# 4.0      64.851351
# 4.1      64.148148
# 3.4      63.846154
# 2.6      62.000000
# 4.8      61.708333
# 3.1      60.645833
# 3.3      60.045455
# 1.6      60.000000
# 1.0      59.000000
# 2.9      58.142857
# 3.0      57.850000
# 4.7      57.250000
# 4.9      57.250000
# 2.2      52.800000
# 2.7      51.625000
# 2.8      47.928571
# 2.0      42.666667
# Industry
#                                            avg_salary
# Industry
# Security Services                          105.500000
# Investment Banking & Asset Management       93.882353
# Energy                                      90.333333
# Oil & Gas Exploration & Production          88.500000
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                          0   1
# Revenue
# $1 to $2 billion (USD)            19  11
# $1 to $5 million (USD)            16   6
# $10 to $25 million (USD)          25  12
# $10+ billion (USD)                42  24
# $100 to $500 million (USD)        77  22
# $2 to $5 billion (USD)            30  14
# $25 to $50 million (USD)          24  21
# $5 to $10 billion (USD)           29  10
# $5 to $10 million (USD)           26   5
# $50 to $100 million (USD)         37   6
# $500 million to $1 billion (USD)  23  16
# Less than $1 million (USD)        21   4
# Unknown / Non-Applicable          68  41

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'sql_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# sql_yn                             0   1
# Revenue
# $1 to $2 billion (USD)            17  13
# $1 to $5 million (USD)             8  14
# $10 to $25 million (USD)          19  18
# $10+ billion (USD)                32  34
# $100 to $500 million (USD)        49  50
# $2 to $5 billion (USD)            25  19
# $25 to $50 million (USD)          10  35
# $5 to $10 billion (USD)           15  24
# $5 to $10 million (USD)           24   7
# $50 to $100 million (USD)         18  25
# $500 million to $1 billion (USD)  12  27
# Less than $1 million (USD)        10  15
# Unknown / Non-Applicable          30  79

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = "".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered=[]
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc = WordCloud(background_color='white', random_state=1, stopwords=STOPWORDS, max_words=2000, width=800, height=1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda_data_da.csv')
