# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned_ds.csv')

# %%
df.head()
# Out:
#                                        Job Title  \
# 0                                 Data Scientist
# 1                             Jr. Data Scientist
# 2                                 Data Scientist
# 3  Senior Engineer/Data Scientist - Industry 4.0
# 4          Principal Scientist / Project Manager
#
#                 Salary Estimate  \
# 0   $87K-$142K (Glassdoor est.)
# 1   $68K-$118K (Glassdoor est.)
# 2   $94K-$155K (Glassdoor est.)
# 3   $89K-$141K (Glassdoor est.)
# 4  $107K-$254K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  At Farm Credit Mid-America, we believe people ...     3.7
# 1  Description\r\n\r\nJob Description:\r\n\r\nWhy...     3.7
# 2  When you’re the best, we’re the best. We insti...     4.0
# 3  Friday, October 30, 2020\r\n\r\n\r\nWatlow Pro...     3.6
# 4  Abbott is a global healthcare leader that help...     3.7
#
#                            Company Name         Location  Headquarters  \
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'company_age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'
    
## Job title and seniority 
		
##  Fix state Los Angeles 

##  Job description length 

##  Competitor count

## hourly wage to annual 

#remove new line from job title

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    381
# analyst           112
# na                108
# data engineer      58
# mle                25
# manager            24
# director            8
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# na        575
# senior    140
# jr          1
# Name: seniority, dtype: int64

# %%
##  Job description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      6609
# 1      5113
# 2      2486
# 3      4161
# 4      5681
#        ...
# 711    9943
# 712    3970
# 713    3160
# 714    1565
# 715    5953
# Name: desc_len, Length: 716, dtype: int64

# %%
# hourly wage to annual
df
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis = 1)

# %%
df[df.hourly ==1][['hourly','min_salary', 'max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 18        1          34          46
# 205       1          34          60
# 269       1          34          56
# 270       1          34          60
# 347       1         102         178
# 372       1         160         276
# 394       1          34          60
# 418       1         102         178
# 514       1         160         276
# 636       1         160         276

# %%
#remove new line from job title
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\r', '').replace('\n', ''))

# %%
df['company_txt']
# Out:
# 0            Farm Credit Mid-America
# 1                             Leidos
# 2                      Vizient, Inc.
# 3      Watlow Electric Manufacturing
# 4                Abbott Laboratories
#                    ...
# 711             Boehringer Ingelheim
# 712                          iRhythm
# 713                              IDT
# 714                     Aptus Health
# 715                    Revive Health
# Name: company_txt, Length: 716, dtype: object

# %%
df.describe()
# Out:
#            Rating  Headquarters      Founded  Competitors      hourly  \
# count  716.000000         716.0   716.000000        716.0  716.000000
# mean     3.779888          -1.0  1867.920391         -1.0    0.013966
# std      0.508488           0.0   451.057580          0.0    0.117434
# min      1.800000          -1.0    -1.000000         -1.0    0.000000
# 25%      3.500000          -1.0  1957.000000         -1.0    0.000000
# 50%      3.700000          -1.0  1991.000000         -1.0    0.000000
# 75%      4.100000          -1.0  2005.000000         -1.0    0.000000
# max      5.000000          -1.0  2019.000000         -1.0    1.000000
#
#          employer  min_salary  max_salary  avg_salary  company_age  \
# count  716.000000  716.000000  716.000000  716.000000   716.000000
# mean     0.001397   76.268156  128.684358  101.666201    41.942737
# std      0.037372   27.233734   40.143705   32.680049    45.433524
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'company_age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority',
#        'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.company_age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['company_age', 'avg_salary', 'Rating'])

# %%
df.boxplot(column = 'Rating')

# %%
df[['company_age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#              company_age  avg_salary    Rating  desc_len
# company_age     1.000000   -0.029619  0.062511  0.222136
# avg_salary     -0.029619    1.000000  0.150974 -0.004023
# Rating          0.062511    0.150974  1.000000 -0.018618
# desc_len        0.222136   -0.004023 -0.018618  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['company_age', 'avg_salary', 'Rating', 'desc_len']].corr(), vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'company_age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority',
#        'desc_len'],
#       dtype='object')

# %%
#location, size, type of ownership, industry, revenue, company_txt, job_state, python_yn, rstudio_yn, spark_yn, aws_yn, excel_yn, sql_yn, job_simp, seniority
df_cat = df[['Location', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue','company_txt','job_state','python_yn', 'rstudio_yn',
       'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority' ]]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("Graph for %s: Total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: Total = 229
# Graph for Size: Total = 8
# Graph for Type of ownership: Total = 9
# Graph for Industry: Total = 66
# Graph for Sector: Total = 24
# Graph for Revenue: Total = 13
# Graph for company_txt: Total = 390
# Graph for job_state: Total = 41
# Graph for python_yn: Total = 2
# Graph for rstudio_yn: Total = 2
# Graph for spark_yn: Total = 2
# Graph for aws_yn: Total = 2
# Graph for excel_yn: Total = 2
# Graph for sql_yn: Total = 2
# Graph for job_simp: Total = 7
# Graph for seniority: Total = 3

# %%
for i in df_cat[['Location', 'company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("Graph for %s: Total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: Total = 20
# Graph for company_txt: Total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'company_age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority',
#        'desc_len'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          70.982143
# data engineer   102.310345
# data scientist  113.167979
# director        102.312500
# manager          91.958333
# mle             133.880000
# na               87.217593

# %%
pd.pivot_table(df, index = ['job_simp', 'seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        na          66.454023
#                senior      86.740000
# data engineer  na          96.565217
#                senior     124.333333
# data scientist jr          93.000000
#                na         109.823620
#                senior     133.731481
# director       na          87.875000
#                senior     116.750000
# manager        na          90.325000
#                senior     100.125000
# mle            na         103.593750
#                senior     187.722222
# na             na          79.953947
#                senior     104.468750

# %%
pd.pivot_table(df, index = ['job_state', 'job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_simp
#  WI       na                       2
#           manager                  3
#           data scientist           2
#           data engineer            1
#           analyst                  3
#  WA       data scientist          16
#           analyst                  1
#           data engineer            1
#           na                       1
#  VA       na                       3
#           mle                      1
#           manager                  2
#           data scientist          42
#           data engineer           14
#           analyst                 11
#  UT       data engineer            1
#           analyst                  6
#           data scientist           7
#  TX       na                       2
#           mle                      1
#           data scientist          12
#           data engineer            9
#           analyst                  6
#  TN       na                       1
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
#  OR        139.000000
#  NC        133.750000
#  CA        132.337079
#  AR        117.000000
#  DC        116.541667
#  AZ        116.000000
#  KY        114.500000
#  MA        114.115385
#  NJ        113.416667
#  NY        109.968750
#  VA        109.321429
#  MD        107.418919
#  TN        107.166667
#  WA        107.031250
#  IL        106.000000
#  OH        105.083333
#  UT        103.357143
#  MI        102.250000
#  PA        101.150000
#  GA        100.166667
#  FL         99.857143
#  CO         97.666667
#  CT         95.500000
#  WI         95.000000
#  TX         94.250000
#  MO         92.875000
#  KS         88.000000
#  MN         83.000000
#  ME         80.500000

# %%
# rating, industry, sector, revenue, number of comp, hourly, employer provided, python, spark, aws, excel, sql, desc_len, type of ownership

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'company_age', 'python_yn', 'rstudio_yn',
#        'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority',
#        'desc_len'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'hourly', 'employer', 'python_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'sql_yn', 'job_simp', 'seniority', 'Type of ownership', 'avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i , values = 'avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
# 2.0     140.000000
# 4.7     121.250000
# 4.0     114.657895
# 5.0     111.750000
# 4.8     109.785714
# 4.5     107.852941
# 4.1     106.487179
# 4.3     106.263158
# 4.4     104.680556
# 4.6     104.357143
# 3.3     103.807692
# 4.2     103.542857
# 2.2     103.000000
# 3.2     102.211538
# 3.5     102.189394
# 3.9     101.037037
# 3.6     100.430000
# 3.7      97.977528
# 3.8      96.433333
# 3.4      95.428571
# 2.6      93.833333
# 2.9      92.125000
# 3.0      91.111111
# 2.8      90.222222
# 4.9      89.200000
# 2.4      83.500000
# 3.1      80.750000
# 1.8      74.500000
# 2.7      74.000000
# 2.3      72.000000
# 2.5      69.875000
# Industry
#                                            avg_salary
# Industry
# Grocery Stores & Supermarkets              146.500000
# Sports & Recreation                        146.000000
# Other Retail Stores                        145.500000
# Department, Clothing, & Shoe Stores        130.166667
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc = 'count')
# Out:
# python_yn                          0    1
# Revenue
# $1 to $2 billion (USD)            13   36
# $1 to $5 million (USD)             5   12
# $10 to $25 million (USD)          28   27
# $10+ billion (USD)                41   91
# $100 to $500 million (USD)        30   64
# $2 to $5 billion (USD)            15   19
# $25 to $50 million (USD)           7   21
# $5 to $10 billion (USD)            7   19
# $5 to $10 million (USD)            4    5
# $50 to $100 million (USD)         20   29
# $500 million to $1 billion (USD)  38   23
# Less than $1 million (USD)         5    4
# Unknown / Non-Applicable          46  107

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = "".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered=[]
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc = WordCloud(background_color='white', random_state=1, stopwords=STOPWORDS, max_words=2000, width=800, height=1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-cc930d70738e> in <module>
#      21 plt.imshow(wc, interpolation="bilinear")
#      22 plt.axis('off')
# ---> 23 plot.show()
#
# NameError: name 'plot' is not defined
